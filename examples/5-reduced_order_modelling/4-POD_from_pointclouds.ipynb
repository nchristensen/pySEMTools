# %% [markdown]
# # POD from pointclouds
#
# We will now proceed to explain how to perform POD from point clouds. In this instance, we test only for POD in serial, as to perform in parallel, a parallel reader/writer is needed.
#
# If you have saved information in hdf5 and have habilitated mpi4py compilation of it, then you could use this code in parallel.

# %% [markdown]
# #### Import general modules

# %%
# Import required modules
from mpi4py import MPI #equivalent to the use of MPI_init() in C
import matplotlib.pyplot as plt
import numpy as np
import h5py

# Get mpi info
comm = MPI.COMM_WORLD

# %% [markdown]
# ## Set up the input parameters

# %%
file_sequence = [f"interpolated_fields{str(1+i).zfill(5)}.hdf5" for i in range(0, 48)]
pod_fields = ["u", "v", "w"]
mesh_fname = "points.hdf5"
mass_matrix_fname = "points.hdf5"
mass_matrix_key = "mass"
k = 10
p = 10

# Calculated parameters
number_of_pod_fields = len(pod_fields)

# %% [markdown]
# ## Call the pynektools routines

# %%
# Import IO helper functions
from pynektools.io.utils import get_fld_from_ndarray

# Import types asociated with POD
from pynektools.rom.pod import POD
from pynektools.rom.io_help import IoHelp

# Output
from pyevtk.hl import gridToVTK

# Load the mesh
with h5py.File(mesh_fname, 'r') as f:
    x = f["x"][:]
    y = f["y"][:]
    z = f["z"][:]

# Load the mass matrix
with h5py.File(mass_matrix_fname, 'r') as f:
    bm = f[mass_matrix_key][:]
bm[np.where(bm == 0)] = 1e-8

# Instance io helper that will serve as buffer for the snapshots
ioh = IoHelp(comm, number_of_fields = number_of_pod_fields, batch_size = p, field_size = bm.size)

# Put the mass matrix in the appropiate format (long 1d array)
mass_list = []
for i in range(0, number_of_pod_fields):
    mass_list.append(np.copy(np.sqrt(bm)))
ioh.copy_fieldlist_to_xi(mass_list)
ioh.bm1sqrt[:,:] = np.copy(ioh.xi[:,:])

# Instance the POD object
pod = POD(comm, number_of_modes_to_update = k, global_updates = True, auto_expand = False)

# Perform reading and updates
j = 0
while j < len(file_sequence):

    # Load the snapshot data
    fname = file_sequence[j]
    with h5py.File(fname, 'r') as f:
        fld_data = []
        for field in pod_fields:
            fld_data.append(f[field][:])

    # Put the snapshot data into a column array
    ioh.copy_fieldlist_to_xi(fld_data)

    # Load the column array into the buffer
    ioh.load_buffer(scale_snapshot = True)
    
    # Update POD modes
    if ioh.update_from_buffer:
        pod.update(comm, buff = ioh.buff[:,:(ioh.buffer_index)])

    j += 1

# Check if there is information in the buffer that should be taken in case the loop exit without flushing
if ioh.buffer_index > ioh.buffer_max_index:
    ioh.log.write("info","All snapshots where properly included in the updates")
else: 
    ioh.log.write("warning","Last loaded snapshot to buffer was: "+repr(ioh.buffer_index-1))
    ioh.log.write("warning","The buffer updates when it is full to position: "+repr(ioh.buffer_max_index))
    ioh.log.write("warning","Data must be updated now to not lose anything,  Performing an update with data in buffer ")
    pod.update(comm, buff = ioh.buff[:,:(ioh.buffer_index)])

# Scale back the modes
pod.scale_modes(comm, bm1sqrt = ioh.bm1sqrt, op = "div")

# Rotate local modes back to global, This only enters in effect if global_update = false
pod.rotate_local_modes_to_global(comm)

# Write the data in vtk for now
# Go over the modes
for j in range(0, k):
    
    ## Split the snapshots into the proper fields
    field_list1d = ioh.split_narray_to_1dfields(pod.u_1t[:,j])
    field_dict = {}
    for i in range(0, len(pod_fields)):
        field_dict[f"{pod_fields[i]}_mode"] = field_list1d[i].reshape(bm.shape)

    # write to vtk
    gridToVTK( "pod_mode"+str(j).zfill(5),  x, y, z, pointData=field_dict)
# Out:
# 2024-09-19 17:11:54,665 - io_helper - INFO - io_helper object initialized
# 2024-09-19 17:11:54,670 - pod - WARNING - ifget_all_modes is hard coded to False. This parameter applies to lcl updates. It controls if one gets all modes in the global rotation, despite keeping less modes locally. I do not see a use for this in production runs. Thus it is set to false. If needed, activate in mpi_spSVD.py module
# 2024-09-19 17:11:54,671 - pod - INFO - POD Object initialized
# 2024-09-19 17:11:54,681 - io_helper - INFO - Loaded snapshot in buffer in pos: 0
# 2024-09-19 17:11:54,687 - io_helper - INFO - Loaded snapshot in buffer in pos: 1
# 2024-09-19 17:11:54,693 - io_helper - INFO - Loaded snapshot in buffer in pos: 2
# 2024-09-19 17:11:54,700 - io_helper - INFO - Loaded snapshot in buffer in pos: 3
# 2024-09-19 17:11:54,706 - io_helper - INFO - Loaded snapshot in buffer in pos: 4
# 2024-09-19 17:11:54,712 - io_helper - INFO - Loaded snapshot in buffer in pos: 5
# 2024-09-19 17:11:54,718 - io_helper - INFO - Loaded snapshot in buffer in pos: 6
# 2024-09-19 17:11:54,725 - io_helper - INFO - Loaded snapshot in buffer in pos: 7
# 2024-09-19 17:11:54,732 - io_helper - INFO - Loaded snapshot in buffer in pos: 8
# 2024-09-19 17:11:54,739 - io_helper - INFO - Loaded snapshot in buffer in pos: 9
# 2024-09-19 17:11:54,740 - io_helper - INFO - Buffer one is full, proceed to update
# 2024-09-19 17:11:54,741 - pod - INFO - Initialized the updating arrays
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:54,842 - pod - INFO - The shape of the modes after this update is U[216000,10]
# 2024-09-19 17:11:54,843 - pod - INFO - The total number of updates performed up to now is: 1
# 2024-09-19 17:11:54,849 - io_helper - INFO - Loaded snapshot in buffer in pos: 0
# 2024-09-19 17:11:54,855 - io_helper - INFO - Loaded snapshot in buffer in pos: 1
# 2024-09-19 17:11:54,861 - io_helper - INFO - Loaded snapshot in buffer in pos: 2
# 2024-09-19 17:11:54,866 - io_helper - INFO - Loaded snapshot in buffer in pos: 3
# 2024-09-19 17:11:54,872 - io_helper - INFO - Loaded snapshot in buffer in pos: 4
# 2024-09-19 17:11:54,877 - io_helper - INFO - Loaded snapshot in buffer in pos: 5
# 2024-09-19 17:11:54,882 - io_helper - INFO - Loaded snapshot in buffer in pos: 6
# 2024-09-19 17:11:54,887 - io_helper - INFO - Loaded snapshot in buffer in pos: 7
# 2024-09-19 17:11:54,894 - io_helper - INFO - Loaded snapshot in buffer in pos: 8
# 2024-09-19 17:11:54,899 - io_helper - INFO - Loaded snapshot in buffer in pos: 9
# 2024-09-19 17:11:54,900 - io_helper - INFO - Buffer one is full, proceed to update
# 2024-09-19 17:11:54,901 - pod - INFO - Performing global SVD #1 in update
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:54,998 - pod - INFO - Appending Vt matrix in update
# 2024-09-19 17:11:54,999 - pod - INFO - Appending New basis to previous ones in update
# 2024-09-19 17:11:55,040 - pod - INFO - Performing global SVD #2 in update
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:55,272 - pod - INFO - The shape of the modes after this update is U[216000,10]
# 2024-09-19 17:11:55,273 - pod - INFO - The total number of updates performed up to now is: 2
# 2024-09-19 17:11:55,278 - io_helper - INFO - Loaded snapshot in buffer in pos: 0
# 2024-09-19 17:11:55,284 - io_helper - INFO - Loaded snapshot in buffer in pos: 1
# 2024-09-19 17:11:55,290 - io_helper - INFO - Loaded snapshot in buffer in pos: 2
# 2024-09-19 17:11:55,296 - io_helper - INFO - Loaded snapshot in buffer in pos: 3
# 2024-09-19 17:11:55,302 - io_helper - INFO - Loaded snapshot in buffer in pos: 4
# 2024-09-19 17:11:55,309 - io_helper - INFO - Loaded snapshot in buffer in pos: 5
# 2024-09-19 17:11:55,314 - io_helper - INFO - Loaded snapshot in buffer in pos: 6
# 2024-09-19 17:11:55,320 - io_helper - INFO - Loaded snapshot in buffer in pos: 7
# 2024-09-19 17:11:55,326 - io_helper - INFO - Loaded snapshot in buffer in pos: 8
# 2024-09-19 17:11:55,332 - io_helper - INFO - Loaded snapshot in buffer in pos: 9
# 2024-09-19 17:11:55,333 - io_helper - INFO - Buffer one is full, proceed to update
# 2024-09-19 17:11:55,334 - pod - INFO - Performing global SVD #1 in update
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:55,421 - pod - INFO - Appending Vt matrix in update
# 2024-09-19 17:11:55,422 - pod - INFO - Appending New basis to previous ones in update
# 2024-09-19 17:11:55,455 - pod - INFO - Performing global SVD #2 in update
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:55,713 - pod - INFO - The shape of the modes after this update is U[216000,10]
# 2024-09-19 17:11:55,715 - pod - INFO - The total number of updates performed up to now is: 3
# 2024-09-19 17:11:55,721 - io_helper - INFO - Loaded snapshot in buffer in pos: 0
# 2024-09-19 17:11:55,728 - io_helper - INFO - Loaded snapshot in buffer in pos: 1
# 2024-09-19 17:11:55,734 - io_helper - INFO - Loaded snapshot in buffer in pos: 2
# 2024-09-19 17:11:55,742 - io_helper - INFO - Loaded snapshot in buffer in pos: 3
# 2024-09-19 17:11:55,751 - io_helper - INFO - Loaded snapshot in buffer in pos: 4
# 2024-09-19 17:11:55,758 - io_helper - INFO - Loaded snapshot in buffer in pos: 5
# 2024-09-19 17:11:55,765 - io_helper - INFO - Loaded snapshot in buffer in pos: 6
# 2024-09-19 17:11:55,771 - io_helper - INFO - Loaded snapshot in buffer in pos: 7
# 2024-09-19 17:11:55,778 - io_helper - INFO - Loaded snapshot in buffer in pos: 8
# 2024-09-19 17:11:55,784 - io_helper - INFO - Loaded snapshot in buffer in pos: 9
# 2024-09-19 17:11:55,784 - io_helper - INFO - Buffer one is full, proceed to update
# 2024-09-19 17:11:55,785 - pod - INFO - Performing global SVD #1 in update
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:55,868 - pod - INFO - Appending Vt matrix in update
# 2024-09-19 17:11:55,869 - pod - INFO - Appending New basis to previous ones in update
# 2024-09-19 17:11:55,902 - pod - INFO - Performing global SVD #2 in update
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:56,165 - pod - INFO - The shape of the modes after this update is U[216000,10]
# 2024-09-19 17:11:56,166 - pod - INFO - The total number of updates performed up to now is: 4
# 2024-09-19 17:11:56,173 - io_helper - INFO - Loaded snapshot in buffer in pos: 0
# 2024-09-19 17:11:56,179 - io_helper - INFO - Loaded snapshot in buffer in pos: 1
# 2024-09-19 17:11:56,185 - io_helper - INFO - Loaded snapshot in buffer in pos: 2
# 2024-09-19 17:11:56,191 - io_helper - INFO - Loaded snapshot in buffer in pos: 3
# 2024-09-19 17:11:56,198 - io_helper - INFO - Loaded snapshot in buffer in pos: 4
# 2024-09-19 17:11:56,203 - io_helper - INFO - Loaded snapshot in buffer in pos: 5
# 2024-09-19 17:11:56,213 - io_helper - INFO - Loaded snapshot in buffer in pos: 6
# 2024-09-19 17:11:56,220 - io_helper - INFO - Loaded snapshot in buffer in pos: 7
# 2024-09-19 17:11:56,225 - io_helper - WARNING - Last loaded snapshot to buffer was: 7
# 2024-09-19 17:11:56,227 - io_helper - WARNING - The buffer updates when it is full to position: 9
# 2024-09-19 17:11:56,228 - io_helper - WARNING - Data must be updated now to not lose anything,  Performing an update with data in buffer
# 2024-09-19 17:11:56,228 - pod - INFO - Performing global SVD #1 in update
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:56,369 - pod - INFO - Appending Vt matrix in update
# 2024-09-19 17:11:56,371 - pod - INFO - Appending New basis to previous ones in update
# 2024-09-19 17:11:56,420 - pod - INFO - Performing global SVD #2 in update
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(y) results
# Performing rotations: local -> global modes
# 2024-09-19 17:11:56,647 - pod - INFO - The shape of the modes after this update is U[216000,10]
# 2024-09-19 17:11:56,649 - pod - INFO - The total number of updates performed up to now is: 5
# 2024-09-19 17:11:56,650 - pod - INFO - Rescaling the obtained modes...
# 2024-09-19 17:11:56,682 - pod - INFO - Rescaling the obtained modes... Done

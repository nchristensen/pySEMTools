# %% [markdown]
# # Perform POD of data that is in disk
#
# For this example we do not include the data in the repository.
#
# So please, work with your own data and experiment!
#
# We do show the general process to follow.
#
# Note that you should check the input.json file to change some of the configuration.
#
# You do not need to do that of course. You can also modify the values directly in this notebook.

# %%
import json
import numpy as np

# Import MPI
from mpi4py import MPI #equivalent to the use of MPI_init() in C

# Split communicator for MPI - MPMD
worldcomm = MPI.COMM_WORLD
worldrank = worldcomm.Get_rank()
worldsize = worldcomm.Get_size()
col = 1
comm = worldcomm.Split(col,worldrank)
rank = comm.Get_rank()
size = comm.Get_size()

# %% [markdown]
# Read the input file

# %%
# Open input file to see path
f = open ("inputs.json", "r") 
params_file = json.loads(f.read())
f.close()

# Read the POD inputs
pod_number_of_snapshots = params_file["number_of_snapshots"]
pod_fields = params_file["fields"]
number_of_pod_fields = len(pod_fields)
pod_batch_size = params_file["batch_size"]
pod_keep_modes = params_file["keep_modes"]
pod_write_modes = params_file["write_modes"]

# %% [markdown]
# Import pynektools functions

# %%
# Import IO helper functions
from pynektools.io.utils import get_fld_from_ndarray, io_path_data

# Import modules for reading and writing
from pynektools.ppymech.neksuite import preadnek, pwritenek
# Import the data types
from pynektools.datatypes.msh import msh_c
from pynektools.datatypes.coef import coef_c
from pynektools.datatypes.field import field_c
from pynektools.datatypes.utils import create_hexadata_from_msh_fld
# Import types asociated with POD
from pynektools.rom.pod import POD_c
from pynektools.rom.io_help import io_help_c

# Read the data paths from the input file
mesh_data = io_path_data(params_file["IO"]["mesh_data"])
field_data = io_path_data(params_file["IO"]["field_data"])

# %% [markdown]
# # Initialize the POD objects

# %%
# Instance the POD object
pod = POD_c(comm, number_of_modes_to_update = pod_keep_modes, global_updates = True, auto_expand = False, threads = 1)

# Initialize the mesh file
path     = mesh_data.dataPath
casename = mesh_data.casename
index    = mesh_data.index
fname    = path+casename+'0.f'+str(index).zfill(5)
data     = preadnek(fname, comm)
msh      = msh_c(comm, data = data)
del data

# Initialize coef to get the mass matrix
coef = coef_c(msh, comm)
bm = coef.B

# Instance io helper that will serve as buffer for the snapshots
ioh = io_help_c(comm, number_of_fields = number_of_pod_fields, batch_size = pod_batch_size, field_size = bm.size)
ioh_unscaled = io_help_c(comm, number_of_fields = number_of_pod_fields, batch_size = pod_batch_size, field_size = bm.size, module_name = "io_helper_2")

# Put the mass matrix in the appropiate format (long 1d array)
mass_list = []
for i in range(0, number_of_pod_fields):
    mass_list.append(np.copy(np.sqrt(bm)))
ioh.copy_fieldlist_to_xi(mass_list)
ioh.bm1sqrt[:,:] = np.copy(ioh.xi[:,:])

# Put the mass matrix in the appropiate format (long 1d array)
mass_list = []
for i in range(0, number_of_pod_fields):
    mass_list.append(np.copy((bm)))
ioh_unscaled.copy_fieldlist_to_xi(mass_list)
ioh_unscaled.bm1[:,:] = np.copy(ioh_unscaled.xi[:,:])
# Out:
# 2024-03-26 21:58:14,785 - pod - WARNING - ifget_all_modes is hard coded to False. This parameter applies to lcl updates. It controls if one gets all modes in the global rotation, despite keeping less modes locally. I do not see a use for this in production runs. Thus it is set to false. If needed, activate in mpi_spSVD.py module (logger.py:63)
# 2024-03-26 21:58:14,786 - pod - INFO - POD Object initialized (logger.py:60)
# 2024-03-26 21:58:38,820 - io_helper - INFO - io_helper object initialized (logger.py:60)
# 2024-03-26 21:58:38,822 - io_helper_2 - INFO - io_helper object initialized (logger.py:60)

# %% [markdown]
# # Stream data and perform SVD

# %%
j = 0
while j < pod_number_of_snapshots:
    
    # Recieve the data from fortran
    path     = field_data.dataPath
    casename = field_data.casename
    index    = field_data.index
    fname=path+casename+'0.f'+str(index + j).zfill(5)
    fld_data = preadnek(fname, comm)
   
    # Get the data in field format
    fld = field_c(comm, data = fld_data)

    # Get the required fields
    u = fld.fields["vel"][0]
    v = fld.fields["vel"][1]
    w = fld.fields["vel"][2]

    u_ = np.copy(u)
    v_ = np.copy(v)
    w_ = np.copy(w)

    # Put the snapshot data into a column array
    ioh.copy_fieldlist_to_xi([u, v, w])
    ioh_unscaled.copy_fieldlist_to_xi([u_, v_, w_])

    # Load the column array into the buffer
    ioh.load_buffer(scale_snapshot = True)
    ioh_unscaled.load_buffer(scale_snapshot = False)
    
    # Update POD modes
    if ioh.update_from_buffer:

        # Find the mean of the snapshots
        ## For the scaled snapshots
        scaled_mean = np.mean(ioh.buff[:,:(ioh.buffer_index)], axis = 1)
        scaled_mean = scaled_mean.reshape(-1,1)
        ## For the unscaled snapshots to be used in the ROM
        s_mean = np.mean(ioh_unscaled.buff[:,:(ioh_unscaled.buffer_index)], axis = 1)
        s_mean = s_mean.reshape(-1,1)

        # Write the means
        field_list1d = ioh.split_narray_to_1dfields(s_mean[:,0])
        u_mean = get_fld_from_ndarray(field_list1d[0], msh.lx, msh.ly, msh.lz, msh.nelv) 
        v_mean = get_fld_from_ndarray(field_list1d[1], msh.lx, msh.ly, msh.lz, msh.nelv) 
        w_mean = get_fld_from_ndarray(field_list1d[2], msh.lx, msh.ly, msh.lz, msh.nelv) 
    
        ## Create an empty field and update its metadata
        out_fld = field_c(comm)
        out_fld.fields["scal"].append(u_mean)
        out_fld.fields["scal"].append(v_mean)
        out_fld.fields["scal"].append(w_mean)
        out_fld.update_vars()
    
        ## Create the hexadata to write out
        out_data = create_hexadata_from_msh_fld(msh = msh, fld = out_fld)
    
        ## Write out a file
        fname = "mean_field0.f"+str(j).zfill(5)
        pwritenek("./"+fname,out_data, comm)
        print("Wrote file: " + fname)
        
        # Subtract the scaled mean from the scaled snapshot before the POD
        ioh.buff[:,:(ioh.buffer_index)] = ioh.buff[:,:(ioh.buffer_index)] - scaled_mean

        # Perform the POD
        pod.update(comm, buff = ioh.buff[:,:(ioh.buffer_index)])


    j += 1
# Out:
# 2024-03-26 21:58:39,440 - io_helper - INFO - Loaded snapshot in buffer in pos: 0 (logger.py:60)
# 2024-03-26 21:58:39,502 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 0 (logger.py:60)
# 2024-03-26 21:58:40,038 - io_helper - INFO - Loaded snapshot in buffer in pos: 1 (logger.py:60)
# 2024-03-26 21:58:40,045 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 1 (logger.py:60)
# 2024-03-26 21:58:40,587 - io_helper - INFO - Loaded snapshot in buffer in pos: 2 (logger.py:60)
# 2024-03-26 21:58:40,594 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 2 (logger.py:60)
# 2024-03-26 21:58:41,138 - io_helper - INFO - Loaded snapshot in buffer in pos: 3 (logger.py:60)
# 2024-03-26 21:58:41,145 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 3 (logger.py:60)
# 2024-03-26 21:58:41,678 - io_helper - INFO - Loaded snapshot in buffer in pos: 4 (logger.py:60)
# 2024-03-26 21:58:41,685 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 4 (logger.py:60)
# 2024-03-26 21:58:42,223 - io_helper - INFO - Loaded snapshot in buffer in pos: 5 (logger.py:60)
# 2024-03-26 21:58:42,230 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 5 (logger.py:60)
# 2024-03-26 21:58:42,762 - io_helper - INFO - Loaded snapshot in buffer in pos: 6 (logger.py:60)
# 2024-03-26 21:58:42,770 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 6 (logger.py:60)
# 2024-03-26 21:58:43,301 - io_helper - INFO - Loaded snapshot in buffer in pos: 7 (logger.py:60)
# 2024-03-26 21:58:43,309 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 7 (logger.py:60)
# 2024-03-26 21:58:43,836 - io_helper - INFO - Loaded snapshot in buffer in pos: 8 (logger.py:60)
# 2024-03-26 21:58:43,843 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 8 (logger.py:60)
# 2024-03-26 21:58:44,371 - io_helper - INFO - Loaded snapshot in buffer in pos: 9 (logger.py:60)
# 2024-03-26 21:58:44,379 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 9 (logger.py:60)
# 2024-03-26 21:58:44,907 - io_helper - INFO - Loaded snapshot in buffer in pos: 10 (logger.py:60)
# 2024-03-26 21:58:44,915 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 10 (logger.py:60)
# 2024-03-26 21:58:45,440 - io_helper - INFO - Loaded snapshot in buffer in pos: 11 (logger.py:60)
# 2024-03-26 21:58:45,447 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 11 (logger.py:60)
# 2024-03-26 21:58:45,984 - io_helper - INFO - Loaded snapshot in buffer in pos: 12 (logger.py:60)
# 2024-03-26 21:58:45,991 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 12 (logger.py:60)
# 2024-03-26 21:58:46,525 - io_helper - INFO - Loaded snapshot in buffer in pos: 13 (logger.py:60)
# 2024-03-26 21:58:46,532 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 13 (logger.py:60)
# 2024-03-26 21:58:47,067 - io_helper - INFO - Loaded snapshot in buffer in pos: 14 (logger.py:60)
# 2024-03-26 21:58:47,074 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 14 (logger.py:60)
# 2024-03-26 21:58:47,610 - io_helper - INFO - Loaded snapshot in buffer in pos: 15 (logger.py:60)
# 2024-03-26 21:58:47,617 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 15 (logger.py:60)
# 2024-03-26 21:58:48,139 - io_helper - INFO - Loaded snapshot in buffer in pos: 16 (logger.py:60)
# 2024-03-26 21:58:48,146 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 16 (logger.py:60)
# 2024-03-26 21:58:48,689 - io_helper - INFO - Loaded snapshot in buffer in pos: 17 (logger.py:60)
# 2024-03-26 21:58:48,697 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 17 (logger.py:60)
# 2024-03-26 21:58:49,226 - io_helper - INFO - Loaded snapshot in buffer in pos: 18 (logger.py:60)
# 2024-03-26 21:58:49,234 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 18 (logger.py:60)
# 2024-03-26 21:58:49,766 - io_helper - INFO - Loaded snapshot in buffer in pos: 19 (logger.py:60)
# 2024-03-26 21:58:49,773 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 19 (logger.py:60)
# 2024-03-26 21:58:50,511 - io_helper - INFO - Loaded snapshot in buffer in pos: 20 (logger.py:60)
# 2024-03-26 21:58:50,519 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 20 (logger.py:60)
# 2024-03-26 21:58:51,052 - io_helper - INFO - Loaded snapshot in buffer in pos: 21 (logger.py:60)
# 2024-03-26 21:58:51,059 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 21 (logger.py:60)
# 2024-03-26 21:58:51,590 - io_helper - INFO - Loaded snapshot in buffer in pos: 22 (logger.py:60)
# 2024-03-26 21:58:51,597 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 22 (logger.py:60)
# 2024-03-26 21:58:52,129 - io_helper - INFO - Loaded snapshot in buffer in pos: 23 (logger.py:60)
# 2024-03-26 21:58:52,137 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 23 (logger.py:60)
# 2024-03-26 21:58:52,666 - io_helper - INFO - Loaded snapshot in buffer in pos: 24 (logger.py:60)
# 2024-03-26 21:58:52,673 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 24 (logger.py:60)
# 2024-03-26 21:58:53,215 - io_helper - INFO - Loaded snapshot in buffer in pos: 25 (logger.py:60)
# 2024-03-26 21:58:53,222 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 25 (logger.py:60)
# 2024-03-26 21:58:53,759 - io_helper - INFO - Loaded snapshot in buffer in pos: 26 (logger.py:60)
# 2024-03-26 21:58:53,766 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 26 (logger.py:60)
# 2024-03-26 21:58:54,322 - io_helper - INFO - Loaded snapshot in buffer in pos: 27 (logger.py:60)
# 2024-03-26 21:58:54,329 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 27 (logger.py:60)
# 2024-03-26 21:58:54,873 - io_helper - INFO - Loaded snapshot in buffer in pos: 28 (logger.py:60)
# 2024-03-26 21:58:54,880 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 28 (logger.py:60)
# 2024-03-26 21:58:55,414 - io_helper - INFO - Loaded snapshot in buffer in pos: 29 (logger.py:60)
# 2024-03-26 21:58:55,421 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 29 (logger.py:60)
# 2024-03-26 21:58:55,957 - io_helper - INFO - Loaded snapshot in buffer in pos: 30 (logger.py:60)
# 2024-03-26 21:58:55,964 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 30 (logger.py:60)
# 2024-03-26 21:58:56,498 - io_helper - INFO - Loaded snapshot in buffer in pos: 31 (logger.py:60)
# 2024-03-26 21:58:56,505 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 31 (logger.py:60)
# 2024-03-26 21:58:57,041 - io_helper - INFO - Loaded snapshot in buffer in pos: 32 (logger.py:60)
# 2024-03-26 21:58:57,049 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 32 (logger.py:60)
# 2024-03-26 21:58:57,583 - io_helper - INFO - Loaded snapshot in buffer in pos: 33 (logger.py:60)
# 2024-03-26 21:58:57,591 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 33 (logger.py:60)
# 2024-03-26 21:58:58,139 - io_helper - INFO - Loaded snapshot in buffer in pos: 34 (logger.py:60)
# 2024-03-26 21:58:58,146 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 34 (logger.py:60)
# 2024-03-26 21:58:58,685 - io_helper - INFO - Loaded snapshot in buffer in pos: 35 (logger.py:60)
# 2024-03-26 21:58:58,692 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 35 (logger.py:60)
# 2024-03-26 21:58:59,220 - io_helper - INFO - Loaded snapshot in buffer in pos: 36 (logger.py:60)
# 2024-03-26 21:58:59,228 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 36 (logger.py:60)
# 2024-03-26 21:58:59,758 - io_helper - INFO - Loaded snapshot in buffer in pos: 37 (logger.py:60)
# 2024-03-26 21:58:59,765 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 37 (logger.py:60)
# 2024-03-26 21:59:00,303 - io_helper - INFO - Loaded snapshot in buffer in pos: 38 (logger.py:60)
# 2024-03-26 21:59:00,310 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 38 (logger.py:60)
# 2024-03-26 21:59:00,853 - io_helper - INFO - Loaded snapshot in buffer in pos: 39 (logger.py:60)
# 2024-03-26 21:59:00,861 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 39 (logger.py:60)
# 2024-03-26 21:59:01,402 - io_helper - INFO - Loaded snapshot in buffer in pos: 40 (logger.py:60)
# 2024-03-26 21:59:01,410 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 40 (logger.py:60)
# 2024-03-26 21:59:01,955 - io_helper - INFO - Loaded snapshot in buffer in pos: 41 (logger.py:60)
# 2024-03-26 21:59:01,963 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 41 (logger.py:60)
# 2024-03-26 21:59:02,502 - io_helper - INFO - Loaded snapshot in buffer in pos: 42 (logger.py:60)
# 2024-03-26 21:59:02,510 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 42 (logger.py:60)
# 2024-03-26 21:59:03,048 - io_helper - INFO - Loaded snapshot in buffer in pos: 43 (logger.py:60)
# 2024-03-26 21:59:03,055 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 43 (logger.py:60)
# 2024-03-26 21:59:03,595 - io_helper - INFO - Loaded snapshot in buffer in pos: 44 (logger.py:60)
# 2024-03-26 21:59:03,602 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 44 (logger.py:60)
# 2024-03-26 21:59:04,131 - io_helper - INFO - Loaded snapshot in buffer in pos: 45 (logger.py:60)
# 2024-03-26 21:59:04,138 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 45 (logger.py:60)
# 2024-03-26 21:59:04,678 - io_helper - INFO - Loaded snapshot in buffer in pos: 46 (logger.py:60)
# 2024-03-26 21:59:04,686 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 46 (logger.py:60)
# 2024-03-26 21:59:05,234 - io_helper - INFO - Loaded snapshot in buffer in pos: 47 (logger.py:60)
# 2024-03-26 21:59:05,242 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 47 (logger.py:60)
# 2024-03-26 21:59:05,788 - io_helper - INFO - Loaded snapshot in buffer in pos: 48 (logger.py:60)
# 2024-03-26 21:59:05,795 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 48 (logger.py:60)
# 2024-03-26 21:59:06,333 - io_helper - INFO - Loaded snapshot in buffer in pos: 49 (logger.py:60)
# 2024-03-26 21:59:06,340 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 49 (logger.py:60)
# 2024-03-26 21:59:06,880 - io_helper - INFO - Loaded snapshot in buffer in pos: 50 (logger.py:60)
# 2024-03-26 21:59:06,887 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 50 (logger.py:60)
# 2024-03-26 21:59:07,432 - io_helper - INFO - Loaded snapshot in buffer in pos: 51 (logger.py:60)
# 2024-03-26 21:59:07,439 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 51 (logger.py:60)
# 2024-03-26 21:59:07,979 - io_helper - INFO - Loaded snapshot in buffer in pos: 52 (logger.py:60)
# 2024-03-26 21:59:07,986 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 52 (logger.py:60)
# 2024-03-26 21:59:08,532 - io_helper - INFO - Loaded snapshot in buffer in pos: 53 (logger.py:60)
# 2024-03-26 21:59:08,539 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 53 (logger.py:60)
# 2024-03-26 21:59:09,072 - io_helper - INFO - Loaded snapshot in buffer in pos: 54 (logger.py:60)
# 2024-03-26 21:59:09,079 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 54 (logger.py:60)
# 2024-03-26 21:59:09,615 - io_helper - INFO - Loaded snapshot in buffer in pos: 55 (logger.py:60)
# 2024-03-26 21:59:09,622 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 55 (logger.py:60)
# 2024-03-26 21:59:10,158 - io_helper - INFO - Loaded snapshot in buffer in pos: 56 (logger.py:60)
# 2024-03-26 21:59:10,165 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 56 (logger.py:60)
# 2024-03-26 21:59:10,690 - io_helper - INFO - Loaded snapshot in buffer in pos: 57 (logger.py:60)
# 2024-03-26 21:59:10,697 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 57 (logger.py:60)
# 2024-03-26 21:59:11,235 - io_helper - INFO - Loaded snapshot in buffer in pos: 58 (logger.py:60)
# 2024-03-26 21:59:11,243 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 58 (logger.py:60)
# 2024-03-26 21:59:11,778 - io_helper - INFO - Loaded snapshot in buffer in pos: 59 (logger.py:60)
# 2024-03-26 21:59:11,785 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 59 (logger.py:60)
# 2024-03-26 21:59:12,322 - io_helper - INFO - Loaded snapshot in buffer in pos: 60 (logger.py:60)
# 2024-03-26 21:59:12,330 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 60 (logger.py:60)
# 2024-03-26 21:59:12,874 - io_helper - INFO - Loaded snapshot in buffer in pos: 61 (logger.py:60)
# 2024-03-26 21:59:12,882 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 61 (logger.py:60)
# 2024-03-26 21:59:13,411 - io_helper - INFO - Loaded snapshot in buffer in pos: 62 (logger.py:60)
# 2024-03-26 21:59:13,418 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 62 (logger.py:60)
# 2024-03-26 21:59:13,953 - io_helper - INFO - Loaded snapshot in buffer in pos: 63 (logger.py:60)
# 2024-03-26 21:59:13,960 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 63 (logger.py:60)
# 2024-03-26 21:59:14,493 - io_helper - INFO - Loaded snapshot in buffer in pos: 64 (logger.py:60)
# 2024-03-26 21:59:14,500 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 64 (logger.py:60)
# 2024-03-26 21:59:15,038 - io_helper - INFO - Loaded snapshot in buffer in pos: 65 (logger.py:60)
# 2024-03-26 21:59:15,045 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 65 (logger.py:60)
# 2024-03-26 21:59:15,585 - io_helper - INFO - Loaded snapshot in buffer in pos: 66 (logger.py:60)
# 2024-03-26 21:59:15,592 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 66 (logger.py:60)
# 2024-03-26 21:59:16,135 - io_helper - INFO - Loaded snapshot in buffer in pos: 67 (logger.py:60)
# 2024-03-26 21:59:16,143 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 67 (logger.py:60)
# 2024-03-26 21:59:16,677 - io_helper - INFO - Loaded snapshot in buffer in pos: 68 (logger.py:60)
# 2024-03-26 21:59:16,684 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 68 (logger.py:60)
# 2024-03-26 21:59:17,220 - io_helper - INFO - Loaded snapshot in buffer in pos: 69 (logger.py:60)
# 2024-03-26 21:59:17,228 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 69 (logger.py:60)
# 2024-03-26 21:59:17,761 - io_helper - INFO - Loaded snapshot in buffer in pos: 70 (logger.py:60)
# 2024-03-26 21:59:17,769 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 70 (logger.py:60)
# 2024-03-26 21:59:18,313 - io_helper - INFO - Loaded snapshot in buffer in pos: 71 (logger.py:60)
# 2024-03-26 21:59:18,320 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 71 (logger.py:60)
# 2024-03-26 21:59:18,859 - io_helper - INFO - Loaded snapshot in buffer in pos: 72 (logger.py:60)
# 2024-03-26 21:59:18,867 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 72 (logger.py:60)
# 2024-03-26 21:59:19,400 - io_helper - INFO - Loaded snapshot in buffer in pos: 73 (logger.py:60)
# 2024-03-26 21:59:19,408 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 73 (logger.py:60)
# 2024-03-26 21:59:19,939 - io_helper - INFO - Loaded snapshot in buffer in pos: 74 (logger.py:60)
# 2024-03-26 21:59:19,946 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 74 (logger.py:60)
# 2024-03-26 21:59:20,494 - io_helper - INFO - Loaded snapshot in buffer in pos: 75 (logger.py:60)
# 2024-03-26 21:59:20,501 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 75 (logger.py:60)
# 2024-03-26 21:59:21,036 - io_helper - INFO - Loaded snapshot in buffer in pos: 76 (logger.py:60)
# 2024-03-26 21:59:21,043 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 76 (logger.py:60)
# 2024-03-26 21:59:21,574 - io_helper - INFO - Loaded snapshot in buffer in pos: 77 (logger.py:60)
# 2024-03-26 21:59:21,581 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 77 (logger.py:60)
# 2024-03-26 21:59:22,108 - io_helper - INFO - Loaded snapshot in buffer in pos: 78 (logger.py:60)
# 2024-03-26 21:59:22,115 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 78 (logger.py:60)
# 2024-03-26 21:59:22,649 - io_helper - INFO - Loaded snapshot in buffer in pos: 79 (logger.py:60)
# 2024-03-26 21:59:22,657 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 79 (logger.py:60)
# 2024-03-26 21:59:23,371 - io_helper - INFO - Loaded snapshot in buffer in pos: 80 (logger.py:60)
# 2024-03-26 21:59:23,379 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 80 (logger.py:60)
# 2024-03-26 21:59:23,916 - io_helper - INFO - Loaded snapshot in buffer in pos: 81 (logger.py:60)
# 2024-03-26 21:59:23,923 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 81 (logger.py:60)
# 2024-03-26 21:59:24,464 - io_helper - INFO - Loaded snapshot in buffer in pos: 82 (logger.py:60)
# 2024-03-26 21:59:24,472 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 82 (logger.py:60)
# 2024-03-26 21:59:25,020 - io_helper - INFO - Loaded snapshot in buffer in pos: 83 (logger.py:60)
# 2024-03-26 21:59:25,027 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 83 (logger.py:60)
# 2024-03-26 21:59:25,576 - io_helper - INFO - Loaded snapshot in buffer in pos: 84 (logger.py:60)
# 2024-03-26 21:59:25,584 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 84 (logger.py:60)
# 2024-03-26 21:59:26,128 - io_helper - INFO - Loaded snapshot in buffer in pos: 85 (logger.py:60)
# 2024-03-26 21:59:26,135 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 85 (logger.py:60)
# 2024-03-26 21:59:26,684 - io_helper - INFO - Loaded snapshot in buffer in pos: 86 (logger.py:60)
# 2024-03-26 21:59:26,691 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 86 (logger.py:60)
# 2024-03-26 21:59:27,228 - io_helper - INFO - Loaded snapshot in buffer in pos: 87 (logger.py:60)
# 2024-03-26 21:59:27,236 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 87 (logger.py:60)
# 2024-03-26 21:59:27,777 - io_helper - INFO - Loaded snapshot in buffer in pos: 88 (logger.py:60)
# 2024-03-26 21:59:27,785 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 88 (logger.py:60)
# 2024-03-26 21:59:28,329 - io_helper - INFO - Loaded snapshot in buffer in pos: 89 (logger.py:60)
# 2024-03-26 21:59:28,336 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 89 (logger.py:60)
# 2024-03-26 21:59:28,878 - io_helper - INFO - Loaded snapshot in buffer in pos: 90 (logger.py:60)
# 2024-03-26 21:59:28,886 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 90 (logger.py:60)
# 2024-03-26 21:59:29,428 - io_helper - INFO - Loaded snapshot in buffer in pos: 91 (logger.py:60)
# 2024-03-26 21:59:29,436 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 91 (logger.py:60)
# 2024-03-26 21:59:29,975 - io_helper - INFO - Loaded snapshot in buffer in pos: 92 (logger.py:60)
# 2024-03-26 21:59:29,982 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 92 (logger.py:60)
# 2024-03-26 21:59:30,523 - io_helper - INFO - Loaded snapshot in buffer in pos: 93 (logger.py:60)
# 2024-03-26 21:59:30,531 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 93 (logger.py:60)
# 2024-03-26 21:59:31,059 - io_helper - INFO - Loaded snapshot in buffer in pos: 94 (logger.py:60)
# 2024-03-26 21:59:31,067 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 94 (logger.py:60)
# 2024-03-26 21:59:31,602 - io_helper - INFO - Loaded snapshot in buffer in pos: 95 (logger.py:60)
# 2024-03-26 21:59:31,610 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 95 (logger.py:60)
# 2024-03-26 21:59:32,145 - io_helper - INFO - Loaded snapshot in buffer in pos: 96 (logger.py:60)
# 2024-03-26 21:59:32,152 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 96 (logger.py:60)
# 2024-03-26 21:59:32,686 - io_helper - INFO - Loaded snapshot in buffer in pos: 97 (logger.py:60)
# 2024-03-26 21:59:32,693 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 97 (logger.py:60)
# 2024-03-26 21:59:33,238 - io_helper - INFO - Loaded snapshot in buffer in pos: 98 (logger.py:60)
# 2024-03-26 21:59:33,245 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 98 (logger.py:60)
# 2024-03-26 21:59:33,778 - io_helper - INFO - Loaded snapshot in buffer in pos: 99 (logger.py:60)
# 2024-03-26 21:59:33,778 - io_helper - INFO - Buffer one is full, proceed to update (logger.py:60)
# 2024-03-26 21:59:33,785 - io_helper_2 - INFO - Loaded snapshot in buffer in pos: 99 (logger.py:60)
# 2024-03-26 21:59:33,786 - io_helper_2 - INFO - Buffer one is full, proceed to update (logger.py:60)
# Wrote file: mean_field0.f00099
# 2024-03-26 21:59:34,946 - pod - INFO - Initialized the updating arrays (logger.py:60)
# Performing individual SVD in each rank
# Calculating eigen matrices in each rank
# Gathering combined eigen matrix in rank 0
# Performing SVD of combined eigen matrix in rank 0
# Broadcasting SVD(Y) results
# Performing rotations: local -> global modes
# 2024-03-26 21:59:39,939 - pod - INFO - The shape of the modes after this update is U[953856,25] (logger.py:60)
# 2024-03-26 21:59:39,940 - pod - INFO - The total number of updates performed up to now is: 1 (logger.py:60)

# %% [markdown]
# # Perform Post - stream operations
#
# So here, we can check if the buffer still has some data that has not been taking into account in the POD.
#
# We also scale back the modes

# %%
# Check if there is information in the buffer that should be taken in case the loop exit without flushing
if ioh.buffer_index > ioh.buffer_max_index:
    ioh.log.write("info","All snapshots where properly included in the updates")
else: 
    ioh.log.write("warning","Last loaded snapshot to buffer was: "+repr(ioh.buffer_index-1))
    ioh.log.write("warning","The buffer updates when it is full to position: "+repr(ioh.buffer_max_index))
    ioh.log.write("warning","Data must be updated now to not lose anything,  Performing an update with data in buffer ")
    pod.update(comm, buff = ioh.buff[:,:(ioh.buffer_index)])

# Scale back the modes
pod.scale_modes(comm, bm1sqrt = ioh.bm1sqrt, op = "div")

# Rotate local modes back to global, This only enters in effect if global_update = false
pod.rotate_local_modes_to_global(comm)
# Out:
# 2024-03-26 21:59:39,946 - io_helper - INFO - All snapshots where properly included in the updates (logger.py:60)
# 2024-03-26 21:59:39,946 - pod - INFO - Rescaling the obtained modes... (logger.py:60)
# 2024-03-26 21:59:40,223 - pod - INFO - Rescaling the obtained modes... Done (logger.py:60)

# %% [markdown]
# # Write data
#
# Write fields with POD modes and npy files with the singular values and vectors

# %%
# Go over the modes
for j in range(0, pod_write_modes):
    
    ## Split the snapshots into the proper fields
    field_list1d = ioh.split_narray_to_1dfields(pod.U_1t[:,j])
    u_mode = get_fld_from_ndarray(field_list1d[0], msh.lx, msh.ly, msh.lz, msh.nelv) 
    v_mode = get_fld_from_ndarray(field_list1d[1], msh.lx, msh.ly, msh.lz, msh.nelv) 
    w_mode = get_fld_from_ndarray(field_list1d[2], msh.lx, msh.ly, msh.lz, msh.nelv) 
    
    ## Create an empty field and update its metadata
    out_fld = field_c(comm)
    out_fld.fields["scal"].append(u_mode)
    out_fld.fields["scal"].append(v_mode)
    out_fld.fields["scal"].append(w_mode)
    out_fld.update_vars()
    
    ## Create the hexadata to write out
    out_data = create_hexadata_from_msh_fld(msh = msh, fld = out_fld)
    
    ## Write out a file
    fname = "modes0.f"+str(j).zfill(5)
    pwritenek("./"+fname,out_data, comm)
    print("Wrote file: " + fname)


if comm.Get_rank() == 0:
    np.save("singular_values", pod.D_1t)
    print("Wrote signular values")
    np.save("right_singular_vectors", pod.Vt_1t)
    print("Wrote right signular values")
# Out:
# Wrote file: modes0.f00000
# Wrote file: modes0.f00001
# Wrote file: modes0.f00002
# Wrote file: modes0.f00003
# Wrote file: modes0.f00004
# Wrote file: modes0.f00005
# Wrote file: modes0.f00006
# Wrote file: modes0.f00007
# Wrote file: modes0.f00008
# Wrote file: modes0.f00009
# Wrote file: modes0.f00010
# Wrote file: modes0.f00011
# Wrote file: modes0.f00012
# Wrote file: modes0.f00013
# Wrote file: modes0.f00014
# Wrote file: modes0.f00015
# Wrote file: modes0.f00016
# Wrote file: modes0.f00017
# Wrote file: modes0.f00018
# Wrote file: modes0.f00019
# Wrote file: modes0.f00020
# Wrote file: modes0.f00021
# Wrote file: modes0.f00022
# Wrote file: modes0.f00023
# Wrote file: modes0.f00024
# Wrote signular values
# Wrote right signular values

# %% [markdown]
# # Visualize some of the data
#
# ## Modes
#
# For this case, visualizing the modes might require paraview or visit. So please go ahead and try
#
# ## Singular values:

# %%
import matplotlib.pyplot as plt

d = np.load("singular_values.npy")

plt.semilogy(d)
plt.show()

# %% [markdown]
# Note how mode 0 has the larger energy, and represents the mean. Afterwards, modes come in pairs of energy, representing traveling waves.
#
# ## Time coefficients

# %%
# Time coefficients read from the POD
vt = np.load("right_singular_vectors.npy")
T = np.diag(d)@vt

# Time coefficients projecting the snapshots into a number of modes
M = 4
snaps = T.shape[1]
aa = np.zeros((M, snaps))
time = np.arange(len(aa[0,:]))*0.5    

for i in range(0,snaps):
    centered_snapshot = (ioh_unscaled.buff[:,i]-s_mean[:,0]).reshape(-1,1)
    projection = pod.U_1t[:, :M].T@(ioh_unscaled.bm1*centered_snapshot)
    aa[:,i] = np.copy(projection[:,0]) # Here, the inner product is with respect to the weights

plt.plot(time, T[0,:])
plt.plot(time, aa[0,:], "--")
plt.xlabel("t")
plt.ylabel("a(t)")

plt.plot(time, T[1,:])
plt.plot(time, aa[1,:], "--")
plt.xlabel("t")
plt.ylabel("a(t)")
plt.show()

# %% [markdown]
# See here how the mode 0 represents the mean flow. And how the paired modes are shifted by a phase of 90 degrees and serve to represent the travelling nature of the wave

# %% [markdown]
# # Galerkin projection based on iliescu
#
# ![image.png](attachment:e1a66a3e-7b19-4cff-b9da-65648e6faad9.png)

# %%
def get_gradU(u, v, w, msh, coef):

    grad = np.zeros((msh.nelv, msh.lz, msh.ly, msh.lx, 3, 3)) # For each point, I get a tensor

    # Fill the Gradient 
    grad[:,:,:,:,0,0] = coef.dudxyz(u, coef.drdx, coef.dsdx, coef.dtdx) #dudx
    grad[:,:,:,:,0,1] = coef.dudxyz(u, coef.drdy, coef.dsdy, coef.dtdy) #dudy
    grad[:,:,:,:,0,2] = coef.dudxyz(u, coef.drdz, coef.dsdz, coef.dtdz) #dudz
    
    grad[:,:,:,:,1,0] = coef.dudxyz(v, coef.drdx, coef.dsdx, coef.dtdx) #dudx
    grad[:,:,:,:,1,1] = coef.dudxyz(v, coef.drdy, coef.dsdy, coef.dtdy) #dudy
    grad[:,:,:,:,1,2] = coef.dudxyz(v, coef.drdz, coef.dsdz, coef.dtdz) #dudz
    
    grad[:,:,:,:,2,0] = coef.dudxyz(w, coef.drdx, coef.dsdx, coef.dtdx) #dudx
    grad[:,:,:,:,2,1] = coef.dudxyz(w, coef.drdy, coef.dsdy, coef.dtdy) #dudy
    grad[:,:,:,:,2,2] = coef.dudxyz(w, coef.drdz, coef.dsdz, coef.dtdz) #dudz

    return grad

def get_gradU_p_gradUT(grad_U, msh):

    grad_U_UT   = np.zeros((msh.nelv, msh.lz, msh.ly, msh.lx, 3, 3)) 
    
    for e in range(0, msh.nelv):
        for k in range(0, msh.lz):
            for j in range(0, msh.ly):
                for i in range(0, msh.lx):
                    grad_U_UT[e, k, j, i, :, :] = grad_U[e, k, j, i, :, :] + grad_U[e, k, j, i, :, :].T 

    return grad_U_UT

def get_UgradU(U, grad_U, msh):

    U_grad_U   = np.zeros((msh.nelv, msh.lz, msh.ly, msh.lx, 3)) # For each point, 3 arrays, one for each velocity
    
    for e in range(0, msh.nelv):
        for k in range(0, msh.lz):
            for j in range(0, msh.ly):
                for i in range(0, msh.lx):
                    U_grad_U[e, k, j, i, :] = (grad_U[e, k, j, i, :, :] @ np.array([U[e, k, j, i, 0], U[e, k, j, i, 1], U[e, k, j, i, 2]]).reshape(-1,1))[:,0] 

    return U_grad_U

# %%
b = np.zeros((M))
A = np.zeros((M, M))
B = np.zeros((M, M, M))

re = 160

# Allocate arrays
phi_k      = np.zeros((msh.nelv, msh.lz, msh.ly, msh.lx, 3)) # For each point, 3 arrays, one for each velocity
phi_m      = np.zeros((msh.nelv, msh.lz, msh.ly, msh.lx, 3)) # For each point, 3 arrays, one for each velocity
phi_n      = np.zeros((msh.nelv, msh.lz, msh.ly, msh.lx, 3)) # For each point, 3 arrays, one for each velocity
U          = np.zeros((msh.nelv, msh.lz, msh.ly, msh.lx, 3)) # For each point, 3 arrays, one for each velocity

# Put data in appropiate format
field_list1d = ioh.split_narray_to_1dfields(s_mean[:,0])
U[:,:,:,:,0] = get_fld_from_ndarray(field_list1d[0], msh.lx, msh.ly, msh.lz, msh.nelv) 
U[:,:,:,:,1] = get_fld_from_ndarray(field_list1d[1], msh.lx, msh.ly, msh.lz, msh.nelv) 
U[:,:,:,:,2] = get_fld_from_ndarray(field_list1d[2], msh.lx, msh.ly, msh.lz, msh.nelv)

bm_for_array = bm.reshape(msh.nelv, msh.lz, msh.ly, msh.lx, 1) # Just reshape in a way that we can broadcast a multiplication operation
bm_for_grad = bm.reshape(msh.nelv, msh.lz, msh.ly, msh.lx, 1, 1) # Just reshape in a way that we can broadcast a multiplication operation

# Get the gradient
grad_U = get_gradU(U[:,:,:,:,0], U[:,:,:,:,1], U[:,:,:,:,2], msh, coef)

# Get the strain matrix
grad_U_UT = get_gradU_p_gradUT(grad_U, msh)

# Get U_grad_U, i.e., non linear term
U_grad_U = get_UgradU(U, grad_U, msh)

from tqdm import tqdm

pbar= tqdm(total=M*M*M)

for k in range(0, M):

    #print("k = {}".format(k))
    
    # Get phi_k
    field_list1d = ioh.split_narray_to_1dfields(pod.U_1t[:,k])
    phi_k[:,:,:,:,0] = get_fld_from_ndarray(field_list1d[0], msh.lx, msh.ly, msh.lz, msh.nelv) 
    phi_k[:,:,:,:,1] = get_fld_from_ndarray(field_list1d[1], msh.lx, msh.ly, msh.lz, msh.nelv) 
    phi_k[:,:,:,:,2] = get_fld_from_ndarray(field_list1d[2], msh.lx, msh.ly, msh.lz, msh.nelv)

    # Grad of phi_k
    grad_phi_k = get_gradU(phi_k[:,:,:,:,0], phi_k[:,:,:,:,1], phi_k[:,:,:,:,2], msh, coef)

    # first inner product in b
    inner_phi_k_U_grad_U = coef.glsum(U_grad_U * phi_k * bm_for_array, comm)
    
    # second inner product in b
    inner_grad_phi_k_grad_UUT_2 = coef.glsum(grad_phi_k * grad_U_UT/2 * bm_for_grad, comm)

    # b
    b[k] = - inner_phi_k_U_grad_U - 2/re * inner_grad_phi_k_grad_UUT_2

    for m in range(0, M):

        #print("m = {}".format(m))

        # Get phi_m
        field_list1d = ioh.split_narray_to_1dfields(pod.U_1t[:,m])
        phi_m[:,:,:,:,0] = get_fld_from_ndarray(field_list1d[0], msh.lx, msh.ly, msh.lz, msh.nelv) 
        phi_m[:,:,:,:,1] = get_fld_from_ndarray(field_list1d[1], msh.lx, msh.ly, msh.lz, msh.nelv) 
        phi_m[:,:,:,:,2] = get_fld_from_ndarray(field_list1d[2], msh.lx, msh.ly, msh.lz, msh.nelv)

        # Grad of phi_m
        grad_phi_m = get_gradU(phi_m[:,:,:,:,0], phi_m[:,:,:,:,1], phi_m[:,:,:,:,2], msh, coef)

        # Get the strain matrix
        grad_phi_m_phi_mT = get_gradU_p_gradUT(grad_phi_m, msh)

        # Get non linear terms
        U_grad_phi_m = get_UgradU(U, grad_phi_m, msh)
        phi_m_grad_U = get_UgradU(phi_m, grad_U, msh)

        
        # first inner product in A
        inner_phi_k_u_grad_phi_m = coef.glsum(phi_k * U_grad_phi_m  * bm_for_array, comm)

        # Second inner product in A
        inner_phi_k_phi_m_grad_u = coef.glsum(phi_k * phi_m_grad_U  * bm_for_array, comm)

        # Third inner product in A
        inner_grad_phi_k_grad_phi_m_phi_mT_2 =  coef.glsum(grad_phi_k * grad_phi_m_phi_mT/2 * bm_for_grad, comm)

        A[k, m] = - inner_phi_k_u_grad_phi_m - inner_phi_k_phi_m_grad_u - 2/re*inner_grad_phi_k_grad_phi_m_phi_mT_2


        for n in range(0, M):

            #print("n = {}".format(n))

            # Get phi_n
            field_list1d = ioh.split_narray_to_1dfields(pod.U_1t[:,n])
            phi_n[:,:,:,:,0] = get_fld_from_ndarray(field_list1d[0], msh.lx, msh.ly, msh.lz, msh.nelv) 
            phi_n[:,:,:,:,1] = get_fld_from_ndarray(field_list1d[1], msh.lx, msh.ly, msh.lz, msh.nelv) 
            phi_n[:,:,:,:,2] = get_fld_from_ndarray(field_list1d[2], msh.lx, msh.ly, msh.lz, msh.nelv)

            # Grad of phi_n
            grad_phi_n = get_gradU(phi_n[:,:,:,:,0], phi_n[:,:,:,:,1], phi_n[:,:,:,:,2], msh, coef)
        
            # Get non linear terms
            phi_m_grad_phi_n = get_UgradU(phi_m, grad_phi_n, msh)

            #first inner product in B
            inner_phi_k_phi_m_grad_phi_n = coef.glsum(phi_k * phi_m_grad_phi_n * bm_for_array, comm)

            B[k,m,n] = - inner_phi_k_phi_m_grad_phi_n

            pbar.update(1)

pbar.close()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [09:35<00:00,  8.99s/it]

# %%
np.save("b", b)
np.save("A", A)
np.save("B", B)

# %% [markdown]
# # Predictions

# %%
# Get initial conditions
a = np.copy(aa[:,0])

# Set up the solver
dt = 1e-5
nn = int(1/dt * 60)
t = -dt
L = np.zeros(M)

# %%
# arrays to store data
tt = []
a_store = np.zeros((M, nn+1))
a_store[:,0] = np.copy(a[:])
t=0
tt.append(t)

# Time stepper
for i in range(0, nn):
    
    t +=dt    
    for k in range(0, M):
        
        L[k] = b[k]
        
        for m in range(0, M):
        
            L[k] = L[k] + A[k,m]*a[m]

        for m in range(0, M):
            for n in range(0, M):
                L[k] =  L[k] + B[k,m,n]*a[n]*a[m]


    for k in range(0, M):
        a[k] = a[k] + dt*L[k]

    tt.append(t)
    a_store[:,i+1] = np.copy(a[:])

# %% [markdown]
# ## Plot predicted time coefficients with the Galerkin POD projection

# %%
plt.plot(tt, a_store[0,:], "-b")
plt.plot(time, aa[0,:], "--b")
plt.plot(tt, a_store[1,:], "-r")
plt.plot(time, aa[1,:], "--r")
plt.xlabel("t")
plt.ylabel("a(t)")
plt.show()

plt.plot(tt, a_store[2,:], "-g")
plt.plot(time, aa[2,:], "--g")
plt.xlabel("t")
plt.ylabel("a(t)")
plt.show()

plt.plot(tt, a_store[3,:], "-y")
plt.plot(time, aa[3,:], "--y")
plt.xlabel("t")
plt.ylabel("a(t)")
plt.show()
